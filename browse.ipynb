# %%
import sys
import os
from blender import convert_file
from mesh_extraction import extract_mesh_names_from_obj
# Out:
# Enabled addon: io_import_dxf
# Enabled addon: mesh_tools
# Enabled addon: add_mesh_extra_objects
# Enabled addon: io_scene_gltf2
# Enabled addon: node_wrangler
# Reloading external rigs...
# Reloading external metarigs...
# Enabled addon: rigify
# Enabled addon: io_mesh_uv_layout
# Enabled addon: mesh_looptools
# Enabled addon: io_anim_camera
# Enabled addon: bone_selection_sets
# Enabled addon: animation_animall
# Enabled addon: add_mesh_discombobulator
# Enabled addon: io_export_dxf
# Enabled addon: magic_uv
# Enabled addon: development_icon_get
# Enabled addon: io_scene_x3d
# Enabled addon: btrace
# Enabled addon: io_anim_nuke_chan
# Enabled addon: mesh_tissue
# Enabled addon: paint_palette
# Enabled addon: object_scatter
# Enabled addon: greasepencil_tools
# Enabled addon: lighting_tri_lights
# Enabled addon: measureit
# Enabled addon: add_curve_ivygen
# Enabled addon: add_camera_rigs
# Enabled addon: copy_global_transform
# Enabled addon: real_snow
# Enabled addon: io_anim_bvh
# ...
